# %% [markdown]
# # 2.- Introducción Python

# %% [markdown]
# ## Import the packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import the data

# %%
raw_csv_data=pd.read_csv("C:/Users/Jorge/Documents/GitHub/curso-series-temporales/1. Introduccion a las series temporales/Python/Index2018.csv")
df_comp=raw_csv_data.copy()

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp.date.describe()
# Out:
# count           6269
# unique          6269
# top       07/01/1994
# freq               1
# Name: date, dtype: object

# %% [markdown]
# ## From text to date

# %%
df_comp.date=pd.to_datetime(df_comp.date, dayfirst=True)

# %%
df_comp.head()
# Out:
#         date     spx      dax     ftse    nikkei
# 0 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1 1994-01-10  475.27  2225.00  3440.58  18443.44
# 2 1994-01-11  474.13  2228.10  3413.77  18485.25
# 3 1994-01-12  474.17  2182.06  3372.02  18793.88
# 4 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df_comp.date.describe(datetime_is_numeric=True)
# Out:
# count                             6269
# mean     2006-01-14 19:36:59.492742144
# min                1994-01-07 00:00:00
# 25%                2000-01-11 00:00:00
# 50%                2006-01-12 00:00:00
# 75%                2012-01-19 00:00:00
# max                2018-01-29 00:00:00
# Name: date, dtype: object

# %% [markdown]
# ## Setting the index

# %%
df_comp.set_index("date", inplace=True)

# %%
df_comp.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# ## Setting the desired frequency

# %%
df_comp=df_comp.asfreq('d')

# %%
df_comp.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-08     NaN      NaN      NaN       NaN
# 1994-01-09     NaN      NaN      NaN       NaN
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25

# %%
df_comp=df_comp.asfreq('b')

# %%
df_comp.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# ## Handling  missing values

# %%
df_comp.isna()
# Out:
#               spx    dax   ftse  nikkei
# date
# 1994-01-07  False  False  False   False
# 1994-01-10  False  False  False   False
# 1994-01-11  False  False  False   False
# 1994-01-12  False  False  False   False
# 1994-01-13  False  False  False   False
# ...           ...    ...    ...     ...
# 2018-01-23  False  False  False   False
# 2018-01-24  False  False  False   False
# 2018-01-25  False  False  False   False
# 2018-01-26  False  False  False   False
# 2018-01-29  False  False  False   False
#
# [6277 rows x 4 columns]

# %%
df_comp.isna().sum()
# Out:
# spx       8
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
df_comp
# Out:
#                     spx       dax         ftse    nikkei
# date
# 1994-01-07   469.900000   2224.95  3445.980000  18124.01
# 1994-01-10   475.270000   2225.00  3440.580000  18443.44
# 1994-01-11   474.130000   2228.10  3413.770000  18485.25
# 1994-01-12   474.170000   2182.06  3372.020000  18793.88
# 1994-01-13   472.470000   2142.37  3360.010000  18577.26
# ...                 ...       ...          ...       ...
# 2018-01-23  2839.130362  13559.60  7731.827774  24124.15
# 2018-01-24  2837.544008  13414.74  7643.428966  23940.78
# 2018-01-25  2839.253031  13298.36  7615.839954  23669.49
# 2018-01-26  2872.867839  13340.17  7665.541292  23631.88
# 2018-01-29  2853.528411  13324.48  7671.533300  23629.34
#
# [6277 rows x 4 columns]

# %%
df_comp.spx=df_comp.spx.fillna(method='ffill')

# %%
df_comp.isna().sum()
# Out:
# spx       0
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
df_comp.dax=df_comp.dax.fillna(value=df_comp.dax.mean())

# %%
df_comp.ftse=df_comp.ftse.fillna(method='bfill')

# %%
df_comp.nikkei=df_comp.nikkei.fillna(method='bfill')

# %%
df_comp.isna().sum()
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# ## Simplifying the dataset

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6277.000000   6277.000000  6277.000000   6277.000000
# mean   1288.642547   6080.063363  5423.690398  14597.597179
# std     487.868210   2752.604984  1145.568370   4043.683038
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     992.715221   4070.460000  4487.880000  10701.130000
# 50%    1233.761241   5774.380000  5663.300000  15030.510000
# 75%    1460.250000   7442.660000  6304.630175  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp['market_value']=df_comp.spx

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei  market_value
# count  6277.000000   6277.000000  6277.000000   6277.000000   6277.000000
# mean   1288.642547   6080.063363  5423.690398  14597.597179   1288.642547
# std     487.868210   2752.604984  1145.568370   4043.683038    487.868210
# min     438.920000   1911.700000  2876.600000   7054.980000    438.920000
# 25%     992.715221   4070.460000  4487.880000  10701.130000    992.715221
# 50%    1233.761241   5774.380000  5663.300000  15030.510000   1233.761241
# 75%    1460.250000   7442.660000  6304.630175  17860.470000   1460.250000
# max    2872.867839  13559.600000  7778.637689  24124.150000   2872.867839

# %%
del df_comp['spx']

# %%
df_comp.describe()
# Out:
#                 dax         ftse        nikkei  market_value
# count   6277.000000  6277.000000   6277.000000   6277.000000
# mean    6080.063363  5423.690398  14597.597179   1288.642547
# std     2752.604984  1145.568370   4043.683038    487.868210
# min     1911.700000  2876.600000   7054.980000    438.920000
# 25%     4070.460000  4487.880000  10701.130000    992.715221
# 50%     5774.380000  5663.300000  15030.510000   1233.761241
# 75%     7442.660000  6304.630175  17860.470000   1460.250000
# max    13559.600000  7778.637689  24124.150000   2872.867839

# %%
del df_comp['dax']
del df_comp['ftse']
del df_comp['nikkei']

# %%
df_comp.describe()
# Out:
#        market_value
# count   6277.000000
# mean    1288.642547
# std      487.868210
# min      438.920000
# 25%      992.715221
# 50%     1233.761241
# 75%     1460.250000
# max     2872.867839

# %% [markdown]
# ## Splitting the data

# %%
size = int(len(df_comp)*0.8)

# %%
df=df_comp.iloc[:size]

# %%
df_test=df_comp.iloc[size:]

# %%
df.tail()
# Out:
#             market_value
# date
# 2013-04-01   1562.173837
# 2013-04-02   1570.252238
# 2013-04-03   1553.686978
# 2013-04-04   1559.979316
# 2013-04-05   1553.278930

# %%
df_test.head()
# Out:
#             market_value
# date
# 2013-04-08   1563.071269
# 2013-04-09   1568.607909
# 2013-04-10   1587.731827
# 2013-04-11   1593.369863
# 2013-04-12   1588.854623

# %% [markdown]
# # 3.- Tabajando con Series de tiempo en Python

# %%
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
sns.set()
# Out:
# C:\Users\Jorge\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# ## White Noise

# %%
wn=np.random.normal(loc = df.market_value.mean(), scale = df.market_value.std(), size = len (df))

# %%
df['wn']=wn
# Out:
# <ipython-input-43-668c275da1fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wn']=wn

# %%
df.describe()
# Out:
#        market_value           wn
# count   5021.000000  5021.000000
# mean    1091.651926  1094.379907
# std      292.559287   290.176263
# min      438.920000   -37.594419
# 25%      914.620000   902.046416
# 50%     1144.650000  1093.172758
# 75%     1316.280729  1287.107747
# max     1570.252238  2140.375543

# %%
df.wn.plot(figsize = (20,5))
plt.title('White Noise Time-Series', size = 24)
plt.show()

# %%
df.market_value.plot(figsize = (20,5))
plt.title('S&P Prices', size = 24)
plt.ylim(0,2300)
plt.show()

# %% [markdown]
# ## Random Walk

# %%
rw = pd.read_csv('C:/Users/Jorge/Documents/GitHub/curso-series-temporales/3. Características fundamentales/Python/Randwalk.csv')

# %%
rw.head()
# Out:
#          date        price
# 0  07/01/1994  1122.139662
# 1  08/01/1994  1135.238562
# 2  09/01/1994  1109.897831
# 3  10/01/1994  1080.347860
# 4  11/01/1994  1082.095245

# %%
rw.date = pd.to_datetime(rw.date, dayfirst=True)
rw.set_index('date',inplace=True)
rw.head()
# Out:
#                   price
# date
# 1994-01-07  1122.139662
# 1994-01-08  1135.238562
# 1994-01-09  1109.897831
# 1994-01-10  1080.347860
# 1994-01-11  1082.095245

# %%
rw=rw.asfreq('b')
rw.describe()
# Out:
#              price
# count  5021.000000
# mean   1269.944293
# std     444.216793
# min     585.483034
# 25%     931.550429
# 50%    1156.363045
# 75%    1488.362029
# max    2715.508720

# %%
df['rw']=rw.price
df.head()
# Out:
# <ipython-input-51-377475afefba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rw']=rw.price
#             market_value           wn           rw
# date
# 1994-01-07        469.90  1331.549702  1122.139662
# 1994-01-10        475.27   663.742044  1080.347860
# 1994-01-11        474.13   953.986027  1082.095245
# 1994-01-12        474.17  1404.649606  1083.639265
# 1994-01-13        472.47  1224.785450  1067.146255

# %%
df.rw.plot(figsize = (20,5))
plt.title('Random Walk', size = 24)
plt.show()

# %%
df.rw.plot(figsize = (20,5))
df.market_value.plot()
plt.title('Random Walk vs S&P', size = 24)
plt.legend()
plt.show()

# %%
# Generamos 500 pasos aleatorios para la caminara, con media 0 y desv tipica 1
steps = np.random.normal(loc=0, scale=1, size=500)
 
# Ponemos el primer elemento a 0 para que el precio inicial sea el que pongamos nosotros
steps[0]=0
 
# Simulando los precios P con un precio inicial de 100
P = 100 + np.cumsum(steps)

# Plot
plt.plot(P)
plt.title("Random Walk Simulada")
plt.show()

# %% [markdown]
# ## Stationarity

# %%
sts.adfuller(df.market_value)
# Out:
# (-1.7369847452352403,
#  0.41216456967706383,
#  18,
#  5002,
#  {'1%': -3.431658008603046,
#   '5%': -2.862117998412982,
#   '10%': -2.567077669247375},
#  39904.880607487445)

# %%
sts.adfuller(df.wn)
# Out:
# (-70.51202487997968,
#  0.0,
#  0,
#  5020,
#  {'1%': -3.431653316130827,
#   '5%': -2.8621159253018247,
#   '10%': -2.5670765656497516},
#  70739.97729041237)

# %%
sts.adfuller(df.rw)
# Out:
# (-1.3286073927689734,
#  0.6159849181617376,
#  24,
#  4996,
#  {'1%': -3.4316595802782865,
#   '5%': -2.8621186927706463,
#   '10%': -2.567078038881065},
#  46299.333497595144)

# %% [markdown]
# ## Seasonality

# %%
s_dec_additive = seasonal_decompose(df.market_value, model = 'additive')
s_dec_additive.plot()
#plt.gcf().set_size_inches(25,15)
plt.show()

# %%
s_dec_multiplicative = seasonal_decompose(df.market_value, model = 'multiplicative')
s_dec_multiplicative.plot()
#plt.gcf().set_size_inches(25,15)
plt.show()

# %% [markdown]
# ## ACF

# %%
sgt.plot_acf(df.market_value, lags = 40, zero = False)
plt.title('ACF S&P', size = 24)
plt.show()

# %%
sgt.plot_acf(df.wn, lags=40, zero=False)
plt.ylim(-0.05,0.05)
plt.title('ACF WN', size=24)
plt.show()

# %%
sgt.plot_acf(df.rw, lags=40, zero=False)
plt.title('ACF RW', size=24)
plt.show()

# %% [markdown]
# # PACF

# %%
sgt.plot_pacf(df.market_value, lags = 40, zero = False, method ='ols')
plt.title('PACF S&P', size = 24)
plt.show()

# %%
sgt.plot_pacf(df.wn, lags = 40, zero = False, method ='ols')
plt.title('PACF S&P', size = 24)
plt.ylim(-0.06,0.06)
plt.show()

# %%
sgt.plot_pacf(df.rw, lags = 40, zero = False, method ='ols')
plt.title('PACF S&P', size = 24)
plt.show()
